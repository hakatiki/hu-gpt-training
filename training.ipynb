# %%
# from utils import *
from transformers import pipeline, set_seed
from datasets import load_dataset, DownloadConfig
from transformers import AutoTokenizer
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer
from tqdm import tqdm

# %%
# download_config = DownloadConfig(delete_extracted=True)
# dataset = load_dataset("json", data_dir="C:/Users/takat/Documents/Programming/Training/data/train.json", streaming=True,)
# dataset = load_dataset("hakatiki/guttenberg-books-corpus",split="train",streaming=True,)

dataset = load_dataset("data/validation",split="validation",streaming=True,)
# Out:
# Using custom data configuration validation-bc27a78d63377863

# %%
dataset
iter_dataset = iter(dataset)

# %%
example = next(iter_dataset)
example
# Out:
# {'text': '> '}

# %%
tokenizer = AutoTokenizer.from_pretrained("hakatiki/hu-gpt")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\takat\Documents\Programming\Training\training.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/takat/Documents/Programming/Training/training.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> tokenizer = AutoTokenizer.from_pretrained("hakatiki/hu-gpt")
#
# File c:\Users\takat\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\auto\tokenization_auto.py:637, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     635 tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#     636 if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 637     return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     638 else:
#     639     if tokenizer_class_py is not None:
#
# File c:\Users\takat\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:1761, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1755     logger.info(
#    1756         f"Can't load following files from cache: {unresolved_files} and cannot check if these "
#    1757         "files are necessary for the tokenizer to operate."
#    1758     )
#    1760 if all(full_file_name is None for full_file_name in resolved_vocab_files.values()):
# -> 1761     raise EnvironmentError(
#    1762         f"Can't load tokenizer for '{pretrained_model_name_or_path}'. If you were trying to load it from "
#    1763         "'https://huggingface.co/models', make sure you don't have a local directory with the same name. "
#    1764         f"Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a directory "
#    1765         f"containing all relevant files for a {cls.__name__} tokenizer."
#    1766     )
#    1768 for file_id, file_path in vocab_files.items():
#    1769     if file_id not in resolved_vocab_files:
#
# OSError: Can't load tokenizer for 'hakatiki/hu-gpt'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'hakatiki/hu-gpt' is the correct path to a directory containing all relevant files for a GPT2TokenizerFast tokenizer.

# %%
tokenizer = AutoTokenizer.from_pretrained("hakatiki/hu-gpt")
config = AutoConfig.from_pretrained("gpt2", vocab_size=len(tokenizer))
model = AutoModelForCausalLM.from_config(config)

# %%
def model_size(model):
    return sum(t.numel() for t in model.parameters())
print(f'GPT-2 size: {model_size(model)/1000**2:.1f}M parameters')
# Out:
# GPT-2 size: 105.5M parameters

# %%
# TODO change it back to True
model.save_pretrained("models/hu-gpt", push_to_hub=True,
                      repo_id="hakatiki/hu-gpt")

# %%
examples, total_characters, total_tokens = 500, 0, 0


for _, example in tqdm(zip(range(examples), iter(dataset)), total=examples):
    total_characters += len(example['text'])
    total_tokens += len(tokenizer(example['text']).tokens())

characters_per_token = total_characters / total_tokens
# Out:
# 100%|██████████| 500/500 [00:09<00:00, 51.89it/s]

# %%
import torch
from torch.utils.data import IterableDataset

class ConstantLengthDataset(IterableDataset):
    
    def __init__(self, tokenizer, dataset, seq_length=1024,
                 num_of_sequences=1024, chars_per_token=3.6):
        self.tokenizer = tokenizer
        self.concat_token_id = tokenizer.eos_token_id
        self.dataset = dataset
        self.seq_length = seq_length
        self.input_characters = seq_length * chars_per_token * num_of_sequences
    
    def __iter__(self):
        iterator = iter(self.dataset)
        more_examples = True
        while more_examples:
            buffer, buffer_len = [], 0
            while True:
                if buffer_len >= self.input_characters:
                    m=f"Buffer full: {buffer_len}>={self.input_characters:.0f}"
                    print(m)
                    break
                try:
                    m=f"Fill buffer: {buffer_len}<{self.input_characters:.0f}"
                    print(m)
                    buffer.append(next(iterator)["text"])
                    buffer_len += len(buffer[-1])
                except StopIteration:
                    iterator = iter(self.dataset)

            all_token_ids = []
            tokenized_inputs = self.tokenizer(buffer, truncation=False)
            for tokenized_input in tokenized_inputs['input_ids']:
                all_token_ids.extend(tokenized_input + [self.concat_token_id])
            
            for i in range(0, len(all_token_ids), self.seq_length):
                input_ids = all_token_ids[i : i + self.seq_length]
                if len(input_ids) == self.seq_length:
                    yield torch.tensor(input_ids)

# %%
# TODO not sure about shuffling
# shuffled_dataset = dataset.shuffle(buffer_size=100)
constant_length_dataset = ConstantLengthDataset(tokenizer, dataset,
                                                num_of_sequences=10)
dataset_iterator = iter(constant_length_dataset)

lengths = [len(b) for _, b in zip(range(5), dataset_iterator)]
print(f"Lengths of the sequences: {lengths}")
# Out:
# Fill buffer: 0<36864
# Fill buffer: 71<36864
# Fill buffer: 71<36864
# Fill buffer: 135<36864
# Fill buffer: 203<36864
# Fill buffer: 270<36864
# Fill buffer: 316<36864
# Fill buffer: 316<36864
# Fill buffer: 316<36864
# Fill buffer: 343<36864
# Fill buffer: 343<36864
# Fill buffer: 365<36864
# Fill buffer: 365<36864
# Fill buffer: 406<36864
# Fill buffer: 406<36864
# Fill buffer: 425<36864
# Fill buffer: 425<36864
# Fill buffer: 454<36864
# Fill buffer: 454<36864
# Fill buffer: 520<36864
# Fill buffer: 520<36864
# Fill buffer: 520<36864
# Fill buffer: 520<36864
# Fill buffer: 520<36864
# Fill buffer: 576<36864
# Fill buffer: 633<36864
# Fill buffer: 657<36864
# Fill buffer: 657<36864
# Fill buffer: 657<36864
# Fill buffer: 657<36864
# Fill buffer: 657<36864
# Fill buffer: 657<36864
# Fill buffer: 657<36864
# Fill buffer: 672<36864
# Fill buffer: 672<36864
# Fill buffer: 692<36864
# Fill buffer: 692<36864
# Fill buffer: 692<36864
# Fill buffer: 692<36864
# Fill buffer: 692<36864
# Fill buffer: 723<36864
# Fill buffer: 723<36864
# Fill buffer: 723<36864
# Fill buffer: 723<36864
# Fill buffer: 723<36864
# Fill buffer: 769<36864
# Fill buffer: 769<36864
# Fill buffer: 769<36864
# Fill buffer: 769<36864
# Fill buffer: 769<36864
# Fill buffer: 777<36864
# Fill buffer: 777<36864
# Fill buffer: 781<36864
# Fill buffer: 781<36864
# Fill buffer: 781<36864
# Fill buffer: 781<36864
# Fill buffer: 781<36864
# Fill buffer: 781<36864
# Fill buffer: 790<36864
# Fill buffer: 790<36864
# Fill buffer: 790<36864
# Fill buffer: 802<36864
# Fill buffer: 818<36864
# Fill buffer: 835<36864
# Fill buffer: 848<36864
# Fill buffer: 865<36864
# Fill buffer: 874<36864
# Fill buffer: 881<36864
# Fill buffer: 901<36864
# Fill buffer: 913<36864
# Fill buffer: 926<36864
# Fill buffer: 934<36864
# Fill buffer: 934<36864
# Fill buffer: 934<36864
# Fill buffer: 934<36864
# Fill buffer: 934<36864
# Fill buffer: 934<36864
# Fill buffer: 934<36864
# Fill buffer: 946<36864
# Fill buffer: 946<36864
# Fill buffer: 946<36864
# Fill buffer: 1007<36864
# Fill buffer: 1074<36864
# Fill buffer: 1137<36864
# Fill buffer: 1137<36864
# Fill buffer: 1206<36864
# Fill buffer: 1267<36864
# Fill buffer: 1300<36864
# Fill buffer: 1300<36864
# Fill buffer: 1369<36864
# Fill buffer: 1419<36864
# Fill buffer: 1419<36864
# Fill buffer: 1490<36864
# Fill buffer: 1561<36864
# Fill buffer: 1633<36864
# Fill buffer: 1652<36864
# Fill buffer: 1652<36864
# Fill buffer: 1711<36864
# Fill buffer: 1777<36864
# Fill buffer: 1793<36864
# Fill buffer: 1793<36864
# Fill buffer: 1865<36864
# Fill buffer: 1883<36864
# Fill buffer: 1883<36864
# Fill buffer: 1945<36864
# Fill buffer: 2010<36864
# Fill buffer: 2021<36864
# Fill buffer: 2021<36864
# Fill buffer: 2092<36864
# Fill buffer: 2128<36864
# Fill buffer: 2128<36864
# Fill buffer: 2180<36864
# Fill buffer: 2180<36864
# Fill buffer: 2252<36864
# Fill buffer: 2312<36864
# Fill buffer: 2312<36864
# Fill buffer: 2382<36864
# Fill buffer: 2454<36864
# Fill buffer: 2483<36864
# Fill buffer: 2483<36864
# Fill buffer: 2552<36864
# Fill buffer: 2619<36864
# Fill buffer: 2685<36864
# Fill buffer: 2727<36864
# Fill buffer: 2727<36864
# Fill buffer: 2799<36864
# Fill buffer: 2865<36864
# Fill buffer: 2887<36864
# Fill buffer: 2887<36864
# Fill buffer: 2954<36864
# Fill buffer: 3025<36864
# Fill buffer: 3063<36864
# Fill buffer: 3063<36864
# Fill buffer: 3132<36864
# Fill buffer: 3168<36864
# Fill buffer: 3168<36864
# Fill buffer: 3238<36864
# Fill buffer: 3305<36864
# Fill buffer: 3336<36864
# Fill buffer: 3336<36864
# Fill buffer: 3404<36864
# Fill buffer: 3404<36864
# Fill buffer: 3475<36864
# Fill buffer: 3540<36864
# Fill buffer: 3608<36864
# Fill buffer: 3679<36864
# Fill buffer: 3747<36864
# Fill buffer: 3815<36864
# Fill buffer: 3886<36864
# Fill buffer: 3904<36864
# Fill buffer: 3904<36864
# Fill buffer: 3963<36864
# Fill buffer: 4033<36864
# Fill buffer: 4074<36864
# Fill buffer: 4074<36864
# Fill buffer: 4145<36864
# Fill buffer: 4208<36864
# Fill buffer: 4278<36864
# Fill buffer: 4344<36864
# Fill buffer: 4409<36864
# Fill buffer: 4462<36864
# Fill buffer: 4462<36864
# Fill buffer: 4516<36864
# Fill buffer: 4516<36864
# Fill buffer: 4578<36864
# Fill buffer: 4647<36864
# Fill buffer: 4716<36864
# Fill buffer: 4746<36864
# Fill buffer: 4746<36864
# Fill buffer: 4812<36864
# Fill buffer: 4879<36864
# Fill buffer: 4888<36864
# Fill buffer: 4888<36864
# Fill buffer: 4957<36864
# Fill buffer: 5004<36864
# Fill buffer: 5004<36864
# Fill buffer: 5066<36864
# Fill buffer: 5066<36864
# Fill buffer: 5131<36864
# Fill buffer: 5195<36864
# Fill buffer: 5206<36864
# Fill buffer: 5206<36864
# Fill buffer: 5274<36864
# Fill buffer: 5274<36864
# Fill buffer: 5346<36864
# Fill buffer: 5346<36864
# Fill buffer: 5418<36864
# Fill buffer: 5418<36864
# Fill buffer: 5488<36864
# Fill buffer: 5556<36864
# Fill buffer: 5622<36864
# Fill buffer: 5634<36864
# Fill buffer: 5634<36864
# Fill buffer: 5705<36864
# Fill buffer: 5776<36864
# Fill buffer: 5842<36864
# Fill buffer: 5862<36864
# Fill buffer: 5862<36864
# Fill buffer: 5931<36864
# Fill buffer: 5951<36864
# Fill buffer: 5951<36864
# Fill buffer: 6017<36864
# Fill buffer: 6042<36864
# Fill buffer: 6042<36864
# Fill buffer: 6092<36864
# Fill buffer: 6092<36864
# Fill buffer: 6164<36864
# Fill buffer: 6231<36864
# Fill buffer: 6296<36864
# Fill buffer: 6362<36864
# Fill buffer: 6430<36864
# Fill buffer: 6500<36864
# Fill buffer: 6570<36864
# Fill buffer: 6641<36864
# Fill buffer: 6705<36864
# Fill buffer: 6769<36864
# Fill buffer: 6832<36864
# Fill buffer: 6892<36864
# Fill buffer: 6959<36864
# Fill buffer: 7016<36864
# Fill buffer: 7016<36864
# Fill buffer: 7067<36864
# Fill buffer: 7067<36864
# Fill buffer: 7128<36864
# Fill buffer: 7194<36864
# Fill buffer: 7266<36864
# Fill buffer: 7337<36864
# Fill buffer: 7409<36864
# Fill buffer: 7481<36864
# Fill buffer: 7505<36864
# Fill buffer: 7505<36864
# Fill buffer: 7573<36864
# Fill buffer: 7642<36864
# Fill buffer: 7714<36864
# Fill buffer: 7769<36864
# Fill buffer: 7769<36864
# Fill buffer: 7797<36864
# Fill buffer: 7797<36864
# Fill buffer: 7859<36864
# Fill buffer: 7923<36864
# Fill buffer: 7949<36864
# Fill buffer: 7949<36864
# Fill buffer: 8016<36864
# Fill buffer: 8076<36864
# Fill buffer: 8144<36864
# Fill buffer: 8186<36864
# Fill buffer: 8186<36864
# Fill buffer: 8247<36864
# Fill buffer: 8313<36864
# Fill buffer: 8313<36864
# Fill buffer: 8385<36864
# Fill buffer: 8450<36864
# Fill buffer: 8517<36864
# Fill buffer: 8583<36864
# Fill buffer: 8654<36864
# Fill buffer: 8665<36864
# Fill buffer: 8665<36864
# Fill buffer: 8734<36864
# Fill buffer: 8754<36864
# Fill buffer: 8754<36864
# Fill buffer: 8815<36864
# Fill buffer: 8827<36864
# Fill buffer: 8827<36864
# Fill buffer: 8891<36864
# Fill buffer: 8942<36864
# Fill buffer: 8942<36864
# Fill buffer: 9012<36864
# Fill buffer: 9069<36864
# Fill buffer: 9087<36864
# Fill buffer: 9087<36864
# Fill buffer: 9152<36864
# Fill buffer: 9165<36864
# Fill buffer: 9165<36864
# Fill buffer: 9226<36864
# Fill buffer: 9298<36864
# Fill buffer: 9367<36864
# Fill buffer: 9378<36864
# Fill buffer: 9378<36864
# Fill buffer: 9420<36864
# Fill buffer: 9420<36864
# Fill buffer: 9482<36864
# Fill buffer: 9482<36864
# Fill buffer: 9552<36864
# Fill buffer: 9616<36864
# Fill buffer: 9616<36864
# Fill buffer: 9688<36864
# Fill buffer: 9754<36864
# Fill buffer: 9763<36864
# Fill buffer: 9763<36864
# Fill buffer: 9826<36864
# Fill buffer: 9896<36864
# Fill buffer: 9896<36864
# Fill buffer: 9966<36864
# Fill buffer: 9998<36864
# Fill buffer: 9998<36864
# Fill buffer: 9998<36864
# Fill buffer: 9998<36864
# Fill buffer: 9998<36864
# Fill buffer: 10014<36864
# Fill buffer: 10014<36864
# Fill buffer: 10014<36864
# Fill buffer: 10084<36864
# Fill buffer: 10103<36864
# Fill buffer: 10103<36864
# Fill buffer: 10173<36864
# Fill buffer: 10233<36864
# Fill buffer: 10233<36864
# Fill buffer: 10298<36864
# Fill buffer: 10327<36864
# Fill buffer: 10327<36864
# Fill buffer: 10395<36864
# Fill buffer: 10462<36864
# Fill buffer: 10528<36864
# Fill buffer: 10594<36864
# Fill buffer: 10665<36864
# Fill buffer: 10731<36864
# Fill buffer: 10795<36864
# Fill buffer: 10859<36864
# Fill buffer: 10924<36864
# Fill buffer: 10996<36864
# Fill buffer: 11065<36864
# Fill buffer: 11135<36864
# Fill buffer: 11192<36864
# Fill buffer: 11217<36864
# Fill buffer: 11217<36864
# Fill buffer: 11282<36864
# Fill buffer: 11320<36864
# Fill buffer: 11320<36864
# Fill buffer: 11390<36864
# Fill buffer: 11423<36864
# Fill buffer: 11423<36864
# Fill buffer: 11488<36864
# Fill buffer: 11545<36864
# Fill buffer: 11577<36864
# Fill buffer: 11577<36864
# Fill buffer: 11639<36864
# Fill buffer: 11649<36864
# Fill buffer: 11649<36864
# Fill buffer: 11719<36864
# Fill buffer: 11780<36864
# Fill buffer: 11791<36864
# Fill buffer: 11791<36864
# Fill buffer: 11861<36864
# Fill buffer: 11930<36864
# Fill buffer: 12002<36864
# Fill buffer: 12021<36864
# Fill buffer: 12021<36864
# Fill buffer: 12084<36864
# Fill buffer: 12113<36864
# Fill buffer: 12113<36864
# Fill buffer: 12177<36864
# Fill buffer: 12243<36864
# Fill buffer: 12304<36864
# Fill buffer: 12315<36864
# Fill buffer: 12315<36864
# Fill buffer: 12333<36864
# Fill buffer: 12333<36864
# Fill buffer: 12405<36864
# Fill buffer: 12475<36864
# Fill buffer: 12543<36864
# Fill buffer: 12611<36864
# Fill buffer: 12676<36864
# Fill buffer: 12742<36864
# Fill buffer: 12812<36864
# Fill buffer: 12875<36864
# Fill buffer: 12940<36864
# Fill buffer: 13010<36864
# Fill buffer: 13079<36864
# Fill buffer: 13144<36864
# Fill buffer: 13214<36864
# Fill buffer: 13284<36864
# Fill buffer: 13352<36864
# Fill buffer: 13402<36864
# Fill buffer: 13402<36864
# Fill buffer: 13468<36864
# Fill buffer: 13534<36864
# Fill buffer: 13603<36864
# Fill buffer: 13670<36864
# Fill buffer: 13742<36864
# Fill buffer: 13750<36864
# Fill buffer: 13750<36864
# Fill buffer: 13821<36864
# Fill buffer: 13891<36864
# Fill buffer: 13958<36864
# Fill buffer: 14028<36864
# Fill buffer: 14093<36864
# Fill buffer: 14093<36864
# Fill buffer: 14163<36864
# Fill buffer: 14232<36864
# Fill buffer: 14301<36864
# Fill buffer: 14373<36864
# Fill buffer: 14405<36864
# Fill buffer: 14405<36864
# Fill buffer: 14473<36864
# Fill buffer: 14543<36864
# Fill buffer: 14543<36864
# Fill buffer: 14611<36864
# Fill buffer: 14654<36864
# Fill buffer: 14654<36864
# Fill buffer: 14726<36864
# Fill buffer: 14797<36864
# Fill buffer: 14841<36864
# Fill buffer: 14841<36864
# Fill buffer: 14907<36864
# Fill buffer: 14952<36864
# Fill buffer: 14952<36864
# Fill buffer: 15020<36864
# Fill buffer: 15091<36864
# Fill buffer: 15160<36864
# Fill buffer: 15231<36864
# Fill buffer: 15302<36864
# Fill buffer: 15368<36864
# Fill buffer: 15438<36864
# Fill buffer: 15508<36864
# Fill buffer: 15580<36864
# Fill buffer: 15601<36864
# Fill buffer: 15601<36864
# Fill buffer: 15667<36864
# Fill buffer: 15702<36864
# Fill buffer: 15702<36864
# Fill buffer: 15774<36864
# Fill buffer: 15844<36864
# Fill buffer: 15905<36864
# Fill buffer: 15941<36864
# Fill buffer: 15941<36864
# Fill buffer: 15995<36864
# Fill buffer: 15995<36864
# Fill buffer: 16060<36864
# Fill buffer: 16132<36864
# Fill buffer: 16183<36864
# Fill buffer: 16183<36864
# Fill buffer: 16237<36864
# Fill buffer: 16237<36864
# Fill buffer: 16270<36864
# Fill buffer: 16270<36864
# Fill buffer: 16342<36864
# Fill buffer: 16381<36864
# Fill buffer: 16381<36864
# Fill buffer: 16451<36864
# Fill buffer: 16487<36864
# Fill buffer: 16487<36864
# Fill buffer: 16504<36864
# Fill buffer: 16504<36864
# Fill buffer: 16572<36864
# Fill buffer: 16640<36864
# Fill buffer: 16705<36864
# Fill buffer: 16772<36864
# Fill buffer: 16841<36864
# Fill buffer: 16879<36864
# Fill buffer: 16879<36864
# Fill buffer: 16948<36864
# Fill buffer: 16982<36864
# Fill buffer: 16982<36864
# Fill buffer: 17049<36864
# Fill buffer: 17093<36864
# Fill buffer: 17093<36864
# Fill buffer: 17156<36864
# Fill buffer: 17217<36864
# Fill buffer: 17285<36864
# Fill buffer: 17296<36864
# Fill buffer: 17296<36864
# Fill buffer: 17361<36864
# Fill buffer: 17375<36864
# Fill buffer: 17375<36864
# Fill buffer: 17443<36864
# Fill buffer: 17496<36864
# Fill buffer: 17496<36864
# Fill buffer: 17567<36864
# Fill buffer: 17631<36864
# Fill buffer: 17697<36864
# Fill buffer: 17763<36864
# Fill buffer: 17823<36864
# Fill buffer: 17887<36864
# Fill buffer: 17956<36864
# Fill buffer: 18014<36864
# Fill buffer: 18014<36864
# Fill buffer: 18081<36864
# Fill buffer: 18153<36864
# Fill buffer: 18221<36864
# Fill buffer: 18285<36864
# Fill buffer: 18355<36864
# Fill buffer: 18427<36864
# Fill buffer: 18498<36864
# Fill buffer: 18567<36864
# Fill buffer: 18635<36864
# Fill buffer: 18707<36864
# Fill buffer: 18772<36864
# Fill buffer: 18842<36864
# Fill buffer: 18907<36864
# Fill buffer: 18972<36864
# Fill buffer: 19036<36864
# Fill buffer: 19066<36864
# Fill buffer: 19066<36864
# Fill buffer: 19132<36864
# Fill buffer: 19198<36864
# Fill buffer: 19269<36864
# Fill buffer: 19336<36864
# Fill buffer: 19361<36864
# Fill buffer: 19361<36864
# Fill buffer: 19432<36864
# Fill buffer: 19497<36864
# Fill buffer: 19567<36864
# Fill buffer: 19616<36864
# Fill buffer: 19616<36864
# Fill buffer: 19687<36864
# Fill buffer: 19754<36864
# Fill buffer: 19812<36864
# Fill buffer: 19812<36864
# Fill buffer: 19878<36864
# Fill buffer: 19949<36864
# Fill buffer: 19998<36864
# Fill buffer: 19998<36864
# Fill buffer: 20059<36864
# Fill buffer: 20123<36864
# Fill buffer: 20191<36864
# Fill buffer: 20256<36864
# Fill buffer: 20324<36864
# Fill buffer: 20350<36864
# Fill buffer: 20350<36864
# Fill buffer: 20394<36864
# Fill buffer: 20394<36864
# Fill buffer: 20461<36864
# Fill buffer: 20529<36864
# Fill buffer: 20529<36864
# Fill buffer: 20598<36864
# Fill buffer: 20660<36864
# Fill buffer: 20729<36864
# Fill buffer: 20758<36864
# Fill buffer: 20758<36864
# Fill buffer: 20826<36864
# Fill buffer: 20897<36864
# Fill buffer: 20940<36864
# Fill buffer: 20940<36864
# Fill buffer: 21012<36864
# Fill buffer: 21080<36864
# Fill buffer: 21147<36864
# Fill buffer: 21218<36864
# Fill buffer: 21282<36864
# Fill buffer: 21346<36864
# Fill buffer: 21417<36864
# Fill buffer: 21478<36864
# Fill buffer: 21550<36864
# Fill buffer: 21615<36864
# Fill buffer: 21687<36864
# Fill buffer: 21727<36864
# Fill buffer: 21727<36864
# Fill buffer: 21796<36864
# Fill buffer: 21868<36864
# Fill buffer: 21927<36864
# Fill buffer: 21927<36864
# Fill buffer: 21988<36864
# Fill buffer: 22053<36864
# Fill buffer: 22116<36864
# Fill buffer: 22116<36864
# Fill buffer: 22166<36864
# Fill buffer: 22166<36864
# Fill buffer: 22235<36864
# Fill buffer: 22301<36864
# Fill buffer: 22319<36864
# Fill buffer: 22319<36864
# Fill buffer: 22389<36864
# Fill buffer: 22461<36864
# Fill buffer: 22530<36864
# Fill buffer: 22595<36864
# Fill buffer: 22651<36864
# Fill buffer: 22651<36864
# Fill buffer: 22722<36864
# Fill buffer: 22761<36864
# Fill buffer: 22761<36864
# Fill buffer: 22831<36864
# Fill buffer: 22869<36864
# Fill buffer: 22869<36864
# Fill buffer: 22894<36864
# Fill buffer: 22894<36864
# Fill buffer: 22965<36864
# Fill buffer: 23036<36864
# Fill buffer: 23059<36864
# Fill buffer: 23059<36864
# Fill buffer: 23129<36864
# Fill buffer: 23181<36864
# Fill buffer: 23181<36864
# Fill buffer: 23223<36864
# Fill buffer: 23223<36864
# Fill buffer: 23293<36864
# Fill buffer: 23360<36864
# Fill buffer: 23407<36864
# Fill buffer: 23407<36864
# Fill buffer: 23407<36864
# Fill buffer: 23407<36864
# Fill buffer: 23407<36864
# Fill buffer: 23424<36864
# Fill buffer: 23424<36864
# Fill buffer: 23424<36864
# Fill buffer: 23493<36864
# Fill buffer: 23562<36864
# Fill buffer: 23624<36864
# Fill buffer: 23645<36864
# Fill buffer: 23645<36864
# Fill buffer: 23666<36864
# Fill buffer: 23666<36864
# Fill buffer: 23734<36864
# Fill buffer: 23803<36864
# Fill buffer: 23803<36864
# Fill buffer: 23871<36864
# Fill buffer: 23906<36864
# Fill buffer: 23906<36864
# Fill buffer: 23976<36864
# Fill buffer: 24048<36864
# Fill buffer: 24118<36864
# Fill buffer: 24160<36864
# Fill buffer: 24160<36864
# Fill buffer: 24228<36864
# Fill buffer: 24263<36864
# Fill buffer: 24263<36864
# Fill buffer: 24296<36864
# Fill buffer: 24296<36864
# Fill buffer: 24331<36864
# Fill buffer: 24331<36864
# Fill buffer: 24403<36864
# Fill buffer: 24473<36864
# Fill buffer: 24529<36864
# Fill buffer: 24601<36864
# Fill buffer: 24672<36864
# Fill buffer: 24705<36864
# Fill buffer: 24705<36864
# Fill buffer: 24771<36864
# Fill buffer: 24843<36864
# Fill buffer: 24911<36864
# Fill buffer: 24982<36864
# Fill buffer: 25039<36864
# Fill buffer: 25039<36864
# Fill buffer: 25093<36864
# Fill buffer: 25093<36864
# Fill buffer: 25162<36864
# Fill buffer: 25224<36864
# Fill buffer: 25293<36864
# Fill buffer: 25360<36864
# Fill buffer: 25431<36864
# Fill buffer: 25479<36864
# Fill buffer: 25479<36864
# Fill buffer: 25550<36864
# Fill buffer: 25550<36864
# Fill buffer: 25618<36864
# Fill buffer: 25626<36864
# Fill buffer: 25626<36864
# Fill buffer: 25664<36864
# Fill buffer: 25664<36864
# Fill buffer: 25727<36864
# Fill buffer: 25794<36864
# Fill buffer: 25857<36864
# Fill buffer: 25926<36864
# Fill buffer: 25995<36864
# Fill buffer: 26059<36864
# Fill buffer: 26131<36864
# Fill buffer: 26197<36864
# Fill buffer: 26255<36864
# Fill buffer: 26323<36864
# Fill buffer: 26393<36864
# Fill buffer: 26464<36864
# Fill buffer: 26534<36864
# Fill buffer: 26598<36864
# Fill buffer: 26670<36864
# Fill buffer: 26735<36864
# Fill buffer: 26806<36864
# Fill buffer: 26806<36864
# Fill buffer: 26876<36864
# Fill buffer: 26946<36864
# Fill buffer: 27015<36864
# Fill buffer: 27015<36864
# Fill buffer: 27087<36864
# Fill buffer: 27158<36864
# Fill buffer: 27172<36864
# Fill buffer: 27172<36864
# Fill buffer: 27244<36864
# Fill buffer: 27313<36864
# Fill buffer: 27326<36864
# Fill buffer: 27326<36864
# Fill buffer: 27397<36864
# Fill buffer: 27468<36864
# Fill buffer: 27490<36864
# Fill buffer: 27490<36864
# Fill buffer: 27556<36864
# Fill buffer: 27623<36864
# Fill buffer: 27692<36864
# Fill buffer: 27763<36864
# Fill buffer: 27827<36864
# Fill buffer: 27827<36864
# Fill buffer: 27897<36864
# Fill buffer: 27969<36864
# Fill buffer: 28040<36864
# Fill buffer: 28101<36864
# Fill buffer: 28173<36864
# Fill buffer: 28244<36864
# Fill buffer: 28316<36864
# Fill buffer: 28375<36864
# Fill buffer: 28375<36864
# Fill buffer: 28446<36864
# Fill buffer: 28454<36864
# Fill buffer: 28454<36864
# Fill buffer: 28519<36864
# Fill buffer: 28584<36864
# Fill buffer: 28653<36864
# Fill buffer: 28669<36864
# Fill buffer: 28669<36864
# Fill buffer: 28736<36864
# Fill buffer: 28807<36864
# Fill buffer: 28879<36864
# Fill buffer: 28949<36864
# Fill buffer: 29021<36864
# Fill buffer: 29086<36864
# Fill buffer: 29129<36864
# Fill buffer: 29129<36864
# Fill buffer: 29200<36864
# Fill buffer: 29263<36864
# Fill buffer: 29321<36864
# Fill buffer: 29321<36864
# Fill buffer: 29370<36864
# Fill buffer: 29370<36864
# Fill buffer: 29439<36864
# Fill buffer: 29511<36864
# Fill buffer: 29580<36864
# Fill buffer: 29652<36864
# Fill buffer: 29702<36864
# Fill buffer: 29702<36864
# Fill buffer: 29774<36864
# Fill buffer: 29843<36864
# Fill buffer: 29914<36864
# Fill buffer: 29981<36864
# Fill buffer: 30048<36864
# Fill buffer: 30120<36864
# Fill buffer: 30164<36864
# Fill buffer: 30164<36864
# Fill buffer: 30227<36864
# Fill buffer: 30299<36864
# Fill buffer: 30337<36864
# Fill buffer: 30337<36864
# Fill buffer: 30355<36864
# Fill buffer: 30355<36864
# Fill buffer: 30422<36864
# Fill buffer: 30492<36864
# Fill buffer: 30559<36864
# Fill buffer: 30602<36864
# Fill buffer: 30602<36864
# Fill buffer: 30624<36864
# Fill buffer: 30624<36864
# Fill buffer: 30637<36864
# Fill buffer: 30637<36864
# Fill buffer: 30699<36864
# Fill buffer: 30770<36864
# Fill buffer: 30842<36864
# Fill buffer: 30913<36864
# Fill buffer: 30957<36864
# Fill buffer: 30957<36864
# Fill buffer: 31027<36864
# Fill buffer: 31096<36864
# Fill buffer: 31102<36864
# Fill buffer: 31102<36864
# Fill buffer: 31174<36864
# Fill buffer: 31174<36864
# Fill buffer: 31245<36864
# Fill buffer: 31315<36864
# Fill buffer: 31355<36864
# Fill buffer: 31355<36864
# Fill buffer: 31423<36864
# Fill buffer: 31487<36864
# Fill buffer: 31554<36864
# Fill buffer: 31619<36864
# Fill buffer: 31619<36864
# Fill buffer: 31662<36864
# Fill buffer: 31662<36864
# Fill buffer: 31733<36864
# Fill buffer: 31802<36864
# Fill buffer: 31866<36864
# Fill buffer: 31923<36864
# Fill buffer: 31923<36864
# Fill buffer: 31989<36864
# Fill buffer: 32060<36864
# Fill buffer: 32107<36864
# Fill buffer: 32107<36864
# Fill buffer: 32177<36864
# Fill buffer: 32232<36864
# Fill buffer: 32232<36864
# Fill buffer: 32275<36864
# Fill buffer: 32275<36864
# Fill buffer: 32309<36864
# Fill buffer: 32309<36864
# Fill buffer: 32380<36864
# Fill buffer: 32436<36864
# Fill buffer: 32436<36864
# Fill buffer: 32507<36864
# Fill buffer: 32524<36864
# Fill buffer: 32524<36864
# Fill buffer: 32555<36864
# Fill buffer: 32555<36864
# Fill buffer: 32622<36864
# Fill buffer: 32663<36864
# Fill buffer: 32663<36864
# Fill buffer: 32710<36864
# Fill buffer: 32710<36864
# Fill buffer: 32772<36864
# Fill buffer: 32772<36864
# Fill buffer: 32844<36864
# Fill buffer: 32844<36864
# Fill buffer: 32913<36864
# Fill buffer: 32922<36864
# Fill buffer: 32922<36864
# Fill buffer: 32994<36864
# Fill buffer: 33008<36864
# Fill buffer: 33008<36864
# Fill buffer: 33033<36864
# Fill buffer: 33033<36864
# Fill buffer: 33104<36864
# Fill buffer: 33171<36864
# Fill buffer: 33239<36864
# Fill buffer: 33245<36864
# Fill buffer: 33245<36864
# Fill buffer: 33316<36864
# Fill buffer: 33354<36864
# Fill buffer: 33354<36864
# Fill buffer: 33425<36864
# Fill buffer: 33496<36864
# Fill buffer: 33563<36864
# Fill buffer: 33632<36864
# Fill buffer: 33695<36864
# Fill buffer: 33766<36864
# Fill buffer: 33830<36864
# Fill buffer: 33893<36864
# Fill buffer: 33893<36864
# Fill buffer: 33963<36864
# Fill buffer: 34028<36864
# Fill buffer: 34096<36864
# Fill buffer: 34166<36864
# Fill buffer: 34214<36864
# Fill buffer: 34214<36864
# Fill buffer: 34280<36864
# Fill buffer: 34289<36864
# Fill buffer: 34289<36864
# Fill buffer: 34357<36864
# Fill buffer: 34425<36864
# Fill buffer: 34463<36864
# Fill buffer: 34463<36864
# Fill buffer: 34535<36864
# Fill buffer: 34601<36864
# Fill buffer: 34671<36864
# Fill buffer: 34737<36864
# Fill buffer: 34803<36864
# Fill buffer: 34874<36864
# Fill buffer: 34894<36864
# Fill buffer: 34894<36864
# Fill buffer: 34966<36864
# Fill buffer: 35010<36864
# Fill buffer: 35010<36864
# Fill buffer: 35062<36864
# Fill buffer: 35062<36864
# Fill buffer: 35122<36864
# Fill buffer: 35134<36864
# Fill buffer: 35134<36864
# Fill buffer: 35204<36864
# Fill buffer: 35213<36864
# Fill buffer: 35213<36864
# Fill buffer: 35272<36864
# Fill buffer: 35272<36864
# Fill buffer: 35307<36864
# Fill buffer: 35307<36864
# Fill buffer: 35376<36864
# Fill buffer: 35447<36864
# Fill buffer: 35519<36864
# Fill buffer: 35574<36864
# Fill buffer: 35574<36864
# Fill buffer: 35646<36864
# Fill buffer: 35712<36864
# Fill buffer: 35779<36864
# Fill buffer: 35843<36864
# Fill buffer: 35843<36864
# Fill buffer: 35911<36864
# Fill buffer: 35911<36864
# Fill buffer: 35982<36864
# Fill buffer: 36054<36864
# Fill buffer: 36121<36864
# Fill buffer: 36140<36864
# Fill buffer: 36140<36864
# Fill buffer: 36210<36864
# Fill buffer: 36273<36864
# Fill buffer: 36343<36864
# Fill buffer: 36360<36864
# Fill buffer: 36360<36864
# Fill buffer: 36411<36864
# Fill buffer: 36411<36864
# Fill buffer: 36480<36864
# Fill buffer: 36498<36864
# Fill buffer: 36498<36864
# Fill buffer: 36543<36864
# Fill buffer: 36543<36864
# Fill buffer: 36613<36864
# Fill buffer: 36613<36864
# Fill buffer: 36682<36864
# Fill buffer: 36727<36864
# Fill buffer: 36727<36864
# Fill buffer: 36765<36864
# Fill buffer: 36765<36864
# Fill buffer: 36829<36864
# Buffer full: 36894>=36864
# Lengths of the sequences: [1024, 1024, 1024, 1024, 1024]

# %%
from argparse import Namespace

# Commented parameters correspond to the small model
config = {"train_batch_size": 2, # 12
          "valid_batch_size": 2, # 12
          "weight_decay": 0.1,
          "shuffle_buffer": 1000,
          "learning_rate": 2e-4, # 5e-4
          "lr_scheduler_type": "cosine",
          "num_warmup_steps": 750, # 2000
          "gradient_accumulation_steps": 16, # 1
          "max_train_steps": 50000, # 150000
          "max_eval_steps": -1,
          "seq_length": 1024,
          "seed": 1,
          "save_checkpoint_steps": 50000} # 15000

args = Namespace(**config)

# %%
from torch.utils.tensorboard import SummaryWriter
import logging
import accelerate
import wandb

def setup_logging(project_name):
    logger = logging.getLogger(__name__)
    logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S", level=logging.INFO, handlers=[
        logging.FileHandler(f"log/debug_{accelerator.process_index}.log"),
        logging.StreamHandler()])
    if accelerator.is_main_process: # We only want to set up logging once
        wandb.init(project=project_name, config=args)
        run_name = wandb.run.name
        tb_writer = SummaryWriter()
        tb_writer.add_hparams(vars(args), {'0': 0})
        logger.setLevel(logging.INFO)
        datasets.utils.logging.set_verbosity_debug()
        transformers.utils.logging.set_verbosity_info()
    else:
        tb_writer = None
        run_name = ''
        logger.setLevel(logging.ERROR)
        datasets.utils.logging.set_verbosity_error()
        transformers.utils.logging.set_verbosity_error()
    return logger, tb_writer, run_name

# %%
def log_metrics(step, metrics):
    logger.info(f"Step {step}: {metrics}")
    if accelerator.is_main_process:
        wandb.log(metrics)
        # [tb_writer.add_scalar(k, v, step) for k, v in metrics.items()]

# %%
#hide_output
from torch.utils.data.dataloader import DataLoader

def create_dataloaders(dataset_name):
    # TODO change it to sreaming=True and remove the shuffle and add validation dataset
    train_data = load_dataset("hakatiki/guttenberg-books-corpus",split="train",streaming=True,)
    # TODO might need this. Not sure
    # train_data = train_data.shuffle(buffer_size=args.shuffle_buffer,
    #                                 seed=args.seed)
    valid_data = load_dataset("hakatiki/guttenberg-books-corpus",split="train",streaming=True,)
    # valid_data = load_dataset(dataset_name+'-valid', split="validation",
    #                           streaming=True)
    
    train_dataset = ConstantLengthDataset(tokenizer, train_data,
                                          seq_length=args.seq_length)
    valid_dataset = ConstantLengthDataset(tokenizer, valid_data,
                                          seq_length=args.seq_length)
    
    train_dataloader=DataLoader(train_dataset, batch_size=args.train_batch_size)
    eval_dataloader=DataLoader(valid_dataset, batch_size=args.valid_batch_size)
    return train_dataloader, eval_dataloader

# %%
def get_grouped_params(model, no_decay=["bias", "LayerNorm.weight"]):
    params_with_wd, params_without_wd = [], []
    for n, p in model.named_parameters():
        if any(nd in n for nd in no_decay):
            params_without_wd.append(p)
        else:
            params_with_wd.append(p)
    return [{'params': params_with_wd, 'weight_decay': args.weight_decay},
            {'params': params_without_wd, 'weight_decay': 0.0}]

# %%
def evaluate():
    model.eval()
    losses = []
    for step, batch in enumerate(eval_dataloader):
        with torch.no_grad():
            outputs = model(batch, labels=batch)
        loss = outputs.loss.repeat(args.valid_batch_size)
        losses.append(accelerator.gather(loss))
        if args.max_eval_steps > 0 and step >= args.max_eval_steps: break
    loss = torch.mean(torch.cat(losses))
    try:
        perplexity = torch.exp(loss)
    except OverflowError:
            perplexity = torch.tensor(float("inf"))
    return loss.item(), perplexity.item()

# %%
set_seed(args.seed)

# Accelerator
accelerator = Accelerator()
samples_per_step = accelerator.state.num_processes * args.train_batch_size

# Logging
logger, tb_writer, run_name = setup_logging(project_name.split("/")[1])
logger.info(accelerator.state)

# Load model and tokenizer
if accelerator.is_main_process:
    hf_repo = Repository("./", clone_from=project_name, revision=run_name)
model = AutoModelForCausalLM.from_pretrained("./", gradient_checkpointing=True)
tokenizer = AutoTokenizer.from_pretrained("./")

# Load dataset and dataloader
train_dataloader, eval_dataloader = create_dataloaders(dataset_name)

# Prepare the optimizer and learning rate scheduler
optimizer = AdamW(get_grouped_params(model), lr=args.learning_rate)
lr_scheduler = get_scheduler(name=args.lr_scheduler_type, optimizer=optimizer,
                             num_warmup_steps=args.num_warmup_steps,
                             num_training_steps=args.max_train_steps,)
def get_lr():
    return optimizer.param_groups[0]['lr']

# Prepare everything with our `accelerator` (order of args is not important)
model, optimizer, train_dataloader, eval_dataloader = accelerator.prepare(
    model, optimizer, train_dataloader, eval_dataloader)

# Train model
model.train()
completed_steps = 0
for step, batch in enumerate(train_dataloader, start=1):
    loss = model(batch, labels=batch).loss
    log_metrics(step, {'lr': get_lr(), 'samples': step*samples_per_step,
                       'steps': completed_steps, 'loss/train': loss.item()})
    loss = loss / args.gradient_accumulation_steps
    accelerator.backward(loss)
    if step % args.gradient_accumulation_steps == 0:
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        completed_steps += 1
    if step % args.save_checkpoint_steps == 0:
        logger.info('Evaluating and saving model checkpoint')
        eval_loss, perplexity = evaluate()
        log_metrics(step, {'loss/eval': eval_loss, 'perplexity': perplexity})
        accelerator.wait_for_everyone()
        unwrapped_model = accelerator.unwrap_model(model)
        if accelerator.is_main_process:
            unwrapped_model.save_pretrained("./")
            hf_repo.push_to_hub(commit_message=f'step {step}')
        model.train()
    if completed_steps >= args.max_train_steps:
        break

# Evaluate and save the last checkpoint
logger.info('Evaluating and saving model after training')
eval_loss, perplexity = evaluate()
log_metrics(step, {'loss/eval': eval_loss, 'perplexity': perplexity})
accelerator.wait_for_everyone()
unwrapped_model = accelerator.unwrap_model(model)
if accelerator.is_main_process:
    unwrapped_model.save_pretrained("./")
    hf_repo.push_to_hub(commit_message=f'final model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\takat\Documents\Programming\Training\training.ipynb Cell 18 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/takat/Documents/Programming/Training/training.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> set_seed(args.seed)
#       <a href='vscode-notebook-cell:/c%3A/Users/takat/Documents/Programming/Training/training.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> # Accelerator
# ----> <a href='vscode-notebook-cell:/c%3A/Users/takat/Documents/Programming/Training/training.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a> accelerator = Accelerator()
#       <a href='vscode-notebook-cell:/c%3A/Users/takat/Documents/Programming/Training/training.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a> samples_per_step = accelerator.state.num_processes * args.train_batch_size
#       <a href='vscode-notebook-cell:/c%3A/Users/takat/Documents/Programming/Training/training.ipynb#X30sZmlsZQ%3D%3D?line=6'>7</a> # Logging
#
# NameError: name 'Accelerator' is not defined
